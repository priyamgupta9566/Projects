# %%
# !pip install face_recognition
# !pip install opencv-python

# %%
import matplotlib.pyplot as plt

from skimage.feature import hog
from skimage import data, exposure
import cv2

image = cv2.imread('Narendra Modi.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16,16),cells_per_block=(1,1), visualize=True, multichannel=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8,4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input Image')

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0,10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
plt.show()
# Out:
# C:\Users\Priyam Gupta\Anaconda3\lib\site-packages\skimage\feature\_hog.py:150: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15. To supress this message specify explicitly the normalization method.
#   skimage_deprecation)

# %%
len(fd)
# Out:
# 1568

# %%
image.shape
# Out:
# (225, 225, 3)

# %%
import face_recognition

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
import numpy as np
import cv2 #OpenCV
# %matplotlib inline

# %%
image = cv2.imread('Leonardo_sketch.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# # Face Detection

# %%
face_locations = face_recognition.face_locations(image)
no_of_faces = len(face_locations)
print("Found {} face(s) in input image." ,format(no_of_faces))
# Out:
# Found {} face(s) in input image. 1

# %%
plt.imshow(image)
ax = plt.gca()

for face_location in face_locations:
  top, right, bottom, left = face_location
  x, y, w, h = left, top, right, bottom

  rect = Rectangle((x,y), w-x, h-y, fill=False, color='red')
  ax.add_patch(rect)

plt.show()

# %% [markdown]
# # Face Recognition

# %% [raw]
# Images Used for training

# %%
image = cv2.imread('Mama2.jpg')
mama = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image = cv2.imread('Shreya.jpg')
shreya = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image = cv2.imread('Sachin Tendulkar.jpg')
sachin = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image = cv2.imread('Narendra Modi.jpg')
Modi = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image = cv2.imread('Leonardo_sketch.jpg')
leonardo = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image = cv2.imread('MS Dhoni.jpg')
dhoni = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image = cv2.imread('Virat Kohli.jpg')
virat = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
sachin_encoding = face_recognition.face_encodings(sachin)[0]
Modi_encoding = face_recognition.face_encodings(Modi)[0]
leonardo_encoding = face_recognition.face_encodings(leonardo)[0]
dhoni_encoding = face_recognition.face_encodings(dhoni)[0]
virat_encoding = face_recognition.face_encodings(virat)[0]
shreya_encoding = face_recognition.face_encodings(shreya)[0]
mama_encoding = face_recognition.face_encodings(mama)[0]

known_face_encodings = [
                        sachin_encoding,
                        Modi_encoding,
                        leonardo_encoding,
                        dhoni_encoding,
                        virat_encoding,
                        shreya_encoding,
                        mama_encoding
]

# %% [markdown]
# # Test 1

# %%
image = cv2.imread('Mama.jpg')
unknown_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings = face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
    results = []
    for known_face_encoding in known_face_encodings:
        d = distance.euclidean(known_face_encoding, unknown_face_encoding)
        results.append(d)
    threshold = 0.6 
    results = np.array(results) <= threshold

    name = "Unknown"

    if results[0]:
      name = "Sachin Tendulakar"
    elif results[1]:
      name = "Narendra Modi"
    elif results[2]:
      name = "Leonardo DiCaprio"
    elif results[3]:
      name = "MS Dhoni"
    elif results[4]:
      name = "Virat Kohli"
    elif results[5]:
      name = "Saggu"
    elif results[6]:
      name = "Mama"




    print(f"found {name} in the photo.")
# Out:
# found Mama in the photo.

# %%
image = cv2.imread('Sachin3.jpg')
unknown_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings = face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
    results = []
    for known_face_encoding in known_face_encodings:
        d = distance.euclidean(known_face_encoding, unknown_face_encoding)
        results.append(d)
    threshold = 0.6 
    results = np.array(results) <= threshold

    name = "Unknown"

    if results[0]:
      name = "Sachin Tendulakar"
    elif results[1]:
      name = "Narendra Modi"
    elif results[2]:
      name = "Leonardo DiCaprio"
    elif results[3]:
      name = "MS Dhoni"
    elif results[4]:
      name = "Virat Kohli"
    elif results[5]:
      name = "Saggu"
    elif results[6]:
      name = "Mama"




    print(f"found {name} in the photo.")
# Out:
#   File "<tokenize>", line 25
#     elif results[6]:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# # Test 2

# %%
image = cv2.imread('Leonardo DiCaprio.jpg')
unknown_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings = face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
    results = []
    for known_face_encoding in known_face_encodings:
        d = distance.euclidean(known_face_encoding, unknown_face_encoding)
        results.append(d)
    threshold = 0.6 
    results = np.array(results) <= threshold

    name = "Unknown"

    if results[0]:
      name = "Sachin Tendulakar"
    elif results[1]:
      name = "Narendra Modi"
    elif results[2]:
      name = "Leonardo DiCaprio"
    elif results[3]:
      name = "MS Dhoni"
    elif results[4]:
      name = "Virat Kohli"



    print(f"found {name} in the photo.")
# Out:
# found Leonardo DiCaprio in the photo.

# %% [markdown]
# # Test 3

# %%
image = cv2.imread('Modi Ji.jpg')
unknown_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings = face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
    results = []
    for known_face_encoding in known_face_encodings:
        d = distance.euclidean(known_face_encoding, unknown_face_encoding)
        results.append(d)
    threshold = 0.6 
    results = np.array(results) <= threshold

    name = "Unknown"

    if results[0]:
      name = "Sachin Tendulakar"
    elif results[1]:
      name = "Narendra Modi"
    elif results[2]:
      name = "Leonardo DiCaprio"
    elif results[3]:
      name = "MS Dhoni"
    elif results[4]:
      name = "Virat Kohli"



    print(f"found {name} in the photo.")

# %% [markdown]
# # Test 4

# %%
image = cv2.imread('MSD2.jpg')
unknown_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings = face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
    results = []
    for known_face_encoding in known_face_encodings:
        d = distance.euclidean(known_face_encoding, unknown_face_encoding)
        results.append(d)
    threshold = 0.6 
    results = np.array(results) <= threshold

    name = "Unknown"

    if results[0]:
      name = "Sachin Tendulakar"
    elif results[1]:
      name = "Narendra Modi"
    elif results[2]:
      name = "Leonardo DiCaprio"
    elif results[3]:
      name = "MS Dhoni"
    elif results[4]:
      name = "Virat Kohli"



    print(f"found {name} in the photo.")

# %% [markdown]
# # Test 5

# %%
image = cv2.imread('Leonardo_sketch.jpg')
unknown_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings = face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
    results = []
    for known_face_encoding in known_face_encodings:
        d = distance.euclidean(known_face_encoding, unknown_face_encoding)
        results.append(d)
    threshold = 0.6 
    results = np.array(results) <= threshold

    name = "Unknown"

    if results[0]:
      name = "Sachin Tendulakar"
    elif results[1]:
      name = "Narendra Modi"
    elif results[2]:
      name = "Leonardo DiCaprio"
    elif results[3]:
      name = "MS Dhoni"
    elif results[4]:
      name = "Virat Kohli"



    print(f"found {name} in the photo.")

# %% [markdown]
# # Facial Landmarks

# %%
image = cv2.imread('Mama.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
face_landmarks_list = face_recognition.face_landmarks(image)

# %%
import matplotlib.lines as mlines
from matplotlib.patches import Polygon

plt.imshow(image)
ax = plt.gca()

for face_landmarks in face_landmarks_list:

    left_eyebrow_pts = face_landmarks['left_eyebrow']
    pre_x, pre_y = left_eyebrow_pts[0]
    for (x,y) in left_eyebrow_pts[1:]:
        l = mlines.Line2D([pre_x,x], [pre_y,y], color='red')
        ax.add_line(l)
        pre_x,pre_y = x,y

    right_eyebrow_pts = face_landmarks['right_eyebrow']
    pre_x, pre_y = right_eyebrow_pts[0]
    for (x,y) in right_eyebrow_pts[1:]:
        l = mlines.Line2D([pre_x,x], [pre_y,y], color='red')
        ax.add_line(l)
        pre_x,pre_y = x,y

    p = Polygon(face_landmarks['top_lip'], facecolor='lightsalmon', edgecolor='orangered')
    ax.add_patch(p)

    p = Polygon(face_landmarks['bottom_lip'], facecolor='lightsalmon', edgecolor='orangered')
    ax.add_patch(p)  

plt.show()

# %%
image = cv2.imread('Saggu.jpg')
unknown_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings = face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
    results = []
    for known_face_encoding in known_face_encodings:
        d = distance.euclidean(known_face_encoding, unknown_face_encoding)
        results.append(d)
    threshold = 0.6 
    results = np.array(results) <= threshold

    name = "Unknown"

    if results[0]:
      name = "Sachin Tendulakar"
    elif results[1]:
      name = "Narendra Modi"
    elif results[2]:
      name = "Leonardo DiCaprio"
    elif results[3]:
      name = "MS Dhoni"
    elif results[4]:
      name = "Virat Kohli"
    elif results[5]:
      name = "Saggu"




    print(f"found {name} in the photo.")
# Out:
# found Saggu in the photo.
